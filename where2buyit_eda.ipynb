# %%
# %matplotlib inline
import os
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
from PIL import ImageOps
from tqdm import tqdm_notebook
from io import BytesIO
import glob
import requests
import numpy as np
import pandas as pd

# %%
photos_df = '/run/media/twoaday/data-storag/data-sets/where2buyit/photos.txt'
photos_df = pd.read_csv(photos_df, error_bad_lines=False, header=None)
photos_df.columns = ['photo_id', 'url']
# Out:
# b'Skipping line 113440: expected 2 fields, saw 3\nSkipping line 113441: expected 2 fields, saw 3\nSkipping line 113442: expected 2 fields, saw 3\nSkipping line 113443: expected 2 fields, saw 3\nSkipping line 113444: expected 2 fields, saw 3\nSkipping line 113445: expected 2 fields, saw 3\nSkipping line 113446: expected 2 fields, saw 3\nSkipping line 113447: expected 2 fields, saw 3\nSkipping line 113448: expected 2 fields, saw 3\nSkipping line 113449: expected 2 fields, saw 3\nSkipping line 113450: expected 2 fields, saw 3\nSkipping line 113451: expected 2 fields, saw 3\nSkipping line 113452: expected 2 fields, saw 3\nSkipping line 113453: expected 2 fields, saw 3\nSkipping line 113454: expected 2 fields, saw 3\nSkipping line 113455: expected 2 fields, saw 3\nSkipping line 113456: expected 2 fields, saw 3\nSkipping line 113457: expected 2 fields, saw 3\nSkipping line 113458: expected 2 fields, saw 3\nSkipping line 113459: expected 2 fields, saw 3\nSkipping line 113460: expected 2 fields, saw 3\nSkipping line 113461: expected 2 fields, saw 3\nSkipping line 113462: expected 2 fields, saw 3\nSkipping line 113463: expected 2 fields, saw 3\nSkipping line 113464: expected 2 fields, saw 3\nSkipping line 113465: expected 2 fields, saw 3\nSkipping line 113466: expected 2 fields, saw 3\nSkipping line 113467: expected 2 fields, saw 3\nSkipping line 113468: expected 2 fields, saw 3\nSkipping line 113469: expected 2 fields, saw 3\nSkipping line 113470: expected 2 fields, saw 3\nSkipping line 113471: expected 2 fields, saw 3\nSkipping line 113472: expected 2 fields, saw 3\nSkipping line 113473: expected 2 fields, saw 3\nSkipping line 113474: expected 2 fields, saw 3\nSkipping line 113475: expected 2 fields, saw 3\nSkipping line 113476: expected 2 fields, saw 3\nSkipping line 113477: expected 2 fields, saw 3\nSkipping line 113478: expected 2 fields, saw 3\nSkipping line 113479: expected 2 fields, saw 3\nSkipping line 113480: expected 2 fields, saw 3\nSkipping line 113481: expected 2 fields, saw 3\nSkipping line 113482: expected 2 fields, saw 3\nSkipping line 113483: expected 2 fields, saw 3\nSkipping line 113484: expected 2 fields, saw 3\nSkipping line 113485: expected 2 fields, saw 3\nSkipping line 113486: expected 2 fields, saw 3\nSkipping line 113487: expected 2 fields, saw 3\nSkipping line 113488: expected 2 fields, saw 3\nSkipping line 113489: expected 2 fields, saw 3\nSkipping line 113490: expected 2 fields, saw 3\nSkipping line 113491: expected 2 fields, saw 3\nSkipping line 113492: expected 2 fields, saw 3\nSkipping line 113493: expected 2 fields, saw 3\nSkipping line 113494: expected 2 fields, saw 3\nSkipping line 113495: expected 2 fields, saw 3\nSkipping line 113496: expected 2 fields, saw 3\nSkipping line 113497: expected 2 fields, saw 3\nSkipping line 113498: expected 2 fields, saw 3\nSkipping line 113499: expected 2 fields, saw 3\nSkipping line 113500: expected 2 fields, saw 3\nSkipping line 113501: expected 2 fields, saw 3\nSkipping line 113502: expected 2 fields, saw 3\nSkipping line 113503: expected 2 fields, saw 3\nSkipping line 113504: expected 2 fields, saw 3\nSkipping line 113505: expected 2 fields, saw 3\nSkipping line 113506: expected 2 fields, saw 3\nSkipping line 113507: expected 2 fields, saw 3\nSkipping line 113508: expected 2 fields, saw 3\nSkipping line 113509: expected 2 fields, saw 3\nSkipping line 113510: expected 2 fields, saw 3\nSkipping line 113511: expected 2 fields, saw 3\nSkipping line 113512: expected 2 fields, saw 3\nSkipping line 113513: expected 2 fields, saw 3\nSkipping line 113514: expected 2 fields, saw 3\nSkipping line 113515: expected 2 fields, saw 3\nSkipping line 113516: expected 2 fields, saw 3\nSkipping line 113517: expected 2 fields, saw 3\nSkipping line 113518: expected 2 fields, saw 3\nSkipping line 113519: expected 2 fields, saw 3\nSkipping line 113520: expected 2 fields, saw 3\nSkipping line 113521: expected 2 fields, saw 3\nSkipping line 113522: expected 2 fields, saw 3\nSkipping line  ...
# b'Skipping line 325411: expected 2 fields, saw 3\nSkipping line 325439: expected 2 fields, saw 3\nSkipping line 325445: expected 2 fields, saw 3\nSkipping line 325448: expected 2 fields, saw 3\nSkipping line 325459: expected 2 fields, saw 3\nSkipping line 325461: expected 2 fields, saw 3\nSkipping line 325481: expected 2 fields, saw 3\nSkipping line 325491: expected 2 fields, saw 3\nSkipping line 325495: expected 2 fields, saw 3\nSkipping line 325525: expected 2 fields, saw 3\nSkipping line 325526: expected 2 fields, saw 3\nSkipping line 325532: expected 2 fields, saw 3\nSkipping line 325534: expected 2 fields, saw 3\nSkipping line 325535: expected 2 fields, saw 3\nSkipping line 325547: expected 2 fields, saw 3\nSkipping line 325548: expected 2 fields, saw 3\nSkipping line 325550: expected 2 fields, saw 3\nSkipping line 325577: expected 2 fields, saw 3\nSkipping line 325579: expected 2 fields, saw 3\nSkipping line 325586: expected 2 fields, saw 3\nSkipping line 325587: expected 2 fields, saw 3\nSkipping line 325592: expected 2 fields, saw 3\nSkipping line 325593: expected 2 fields, saw 3\nSkipping line 325610: expected 2 fields, saw 3\nSkipping line 325622: expected 2 fields, saw 3\nSkipping line 325625: expected 2 fields, saw 3\nSkipping line 325630: expected 2 fields, saw 3\nSkipping line 325643: expected 2 fields, saw 3\nSkipping line 325645: expected 2 fields, saw 3\nSkipping line 325650: expected 2 fields, saw 3\nSkipping line 325661: expected 2 fields, saw 3\nSkipping line 325664: expected 2 fields, saw 3\nSkipping line 325671: expected 2 fields, saw 3\nSkipping line 325673: expected 2 fields, saw 3\nSkipping line 325674: expected 2 fields, saw 3\nSkipping line 325687: expected 2 fields, saw 3\nSkipping line 325696: expected 2 fields, saw 3\nSkipping line 325703: expected 2 fields, saw 3\nSkipping line 325704: expected 2 fields, saw 3\nSkipping line 325705: expected 2 fields, saw 3\nSkipping line 325713: expected 2 fields, saw 3\nSkipping line 325728: expected 2 fields, saw 3\nSkipping line 325729: expected 2 fields, saw 3\nSkipping line 325730: expected 2 fields, saw 3\nSkipping line 325742: expected 2 fields, saw 3\nSkipping line 325746: expected 2 fields, saw 3\nSkipping line 325747: expected 2 fields, saw 3\nSkipping line 325758: expected 2 fields, saw 3\nSkipping line 325759: expected 2 fields, saw 3\nSkipping line 325760: expected 2 fields, saw 3\nSkipping line 325762: expected 2 fields, saw 3\nSkipping line 325764: expected 2 fields, saw 3\nSkipping line 325765: expected 2 fields, saw 3\nSkipping line 325766: expected 2 fields, saw 3\nSkipping line 325767: expected 2 fields, saw 3\nSkipping line 325768: expected 2 fields, saw 3\nSkipping line 325769: expected 2 fields, saw 3\nSkipping line 325784: expected 2 fields, saw 3\nSkipping line 325789: expected 2 fields, saw 3\nSkipping line 325791: expected 2 fields, saw 3\nSkipping line 325802: expected 2 fields, saw 3\nSkipping line 325803: expected 2 fields, saw 3\nSkipping line 325808: expected 2 fields, saw 3\nSkipping line 325809: expected 2 fields, saw 3\nSkipping line 325813: expected 2 fields, saw 3\nSkipping line 325828: expected 2 fields, saw 3\nSkipping line 325839: expected 2 fields, saw 3\nSkipping line 325842: expected 2 fields, saw 3\nSkipping line 325849: expected 2 fields, saw 3\nSkipping line 325850: expected 2 fields, saw 3\nSkipping line 325853: expected 2 fields, saw 3\nSkipping line 325854: expected 2 fields, saw 3\nSkipping line 325861: expected 2 fields, saw 3\nSkipping line 325868: expected 2 fields, saw 3\nSkipping line 325869: expected 2 fields, saw 3\nSkipping line 325872: expected 2 fields, saw 3\nSkipping line 325874: expected 2 fields, saw 3\nSkipping line 325875: expected 2 fields, saw 3\nSkipping line 325876: expected 2 fields, saw 3\nSkipping line 325879: expected 2 fields, saw 3\nSkipping line 325893: expected 2 fields, saw 3\nSkipping line 325921: expected 2 fields, saw 3\nSkipping line 325927: expected 2 fields, saw 3\nSkipping line  ...

# %%
photos_df.count()
# Out:
# photo_id    407963
# url         407963
# dtype: int64

# %%
df_bags = '/run/media/twoaday/data-storag/data-sets/where2buyit/meta/json/retrieval_bags.json'
df_bags = pd.read_json(df_bags)

# %%
df_bags.head()
# Out:
#     photo  product
# 0   75161        1
# 1   75162        1
# 2  249331        2
# 3  206867        3
# 4  371076        4

# %%
df_bags.groupby('product').count().photo.hist(bins=14)

# %%
df_bags_pairs = '/run/media/twoaday/data-storag/data-sets/where2buyit/meta/json/test_pairs_bags.json'
df_bags_pairs = pd.read_json(df_bags_pairs)

# %%
df_bags_pairs.groupby('photo').count().bbox.hist(bins=14)

# %%
df_bags_pairs.groupby('product').count().photo.hist(bins=14)

# %%
df_bags_pairs.head()
# Out:
#                                                 bbox  photo  product
# 0  {'width': 120, 'top': 172, 'height': 358, 'lef...   4534     7419
# 1  {'width': 120, 'top': 184, 'height': 303, 'lef...  16159     9946
# 2  {'width': 57, 'top': 310, 'height': 88, 'left'...   6538    10777
# 3  {'width': 241, 'top': 516, 'height': 300, 'lef...   9473     7862
# 4  {'width': 258, 'top': 498, 'height': 641, 'lef...   8489    10610

# %%
def show_img_with_plot(img_id, bbox):
    
    img = requests.get(photos_df.loc[photos_df.photo_id == img_id].url.values[0]).content
    img = Image.open(BytesIO(img))
    im = np.array(img, dtype=np.uint8)
    print(img_id)
    print(im.shape)
    print(bbox)
    # Create figure and axes
    fig,ax = plt.subplots(1)
    # Display the image
    ax.imshow(im)
    # Create a Rectangle patch
    rect = patches.Rectangle((bbox['left'], bbox['top']),
                             bbox['width'],
                             bbox['height'],
                             linewidth=3,
                             edgecolor='g',
                             facecolor='none')
    # Add the patch to the Axes
    ax.add_patch(rect)
    plt.show()

# %%
def show_img(img_id):
    img = requests.get(photos_df.loc[photos_df.photo_id == img_id].url.values[0]).content
    img = Image.open(BytesIO(img))
    im = np.array(img, dtype=np.uint8)
    # Create figure and axes
    fig,ax = plt.subplots(1)
    # Display the image
    ax.imshow(im)
    plt.show()

# %%
sample = df_bags_pairs.sample(1)
sample = sample[['bbox', 'photo', 'product']].values[0]
show_img_with_plot(sample[1], sample[0])
for img_id in df_bags.loc[df_bags['product'] == sample[2]].photo.values:
    show_img(img_id)
# Out:
# 9695
# (612, 612, 3)
# {'width': 91, 'top': 107, 'height': 302, 'left': 49}

# %%
pair_file_list = glob.glob("/run/media/twoaday/data-storag/data-sets/where2buyit/meta/json/*.json")
pair_file_list = [p for p in pair_file_list if '_pairs_' in p]
pair_file_list = [p for p in pair_file_list if 'train_' in p]
total_num_of_photos = 0
for p in pair_file_list:
    total_num_of_photos += pd.read_json(p).groupby('product').count().photo.sum()
total_num_of_photos
# Out:
# 30629

# %%
pair_file_list
# Out:
# ['/run/media/twoaday/data-storag/data-sets/where2buyit/meta/json/train_pairs_bags.json',
#  '/run/media/twoaday/data-storag/data-sets/where2buyit/meta/json/train_pairs_belts.json',
#  '/run/media/twoaday/data-storag/data-sets/where2buyit/meta/json/train_pairs_dresses.json',
#  '/run/media/twoaday/data-storag/data-sets/where2buyit/meta/json/train_pairs_eyewear.json',
#  '/run/media/twoaday/data-storag/data-sets/where2buyit/meta/json/train_pairs_footwear.json',
#  '/run/media/twoaday/data-storag/data-sets/where2buyit/meta/json/train_pairs_hats.json',
#  '/run/media/twoaday/data-storag/data-sets/where2buyit/meta/json/train_pairs_leggings.json',
#  '/run/media/twoaday/data-storag/data-sets/where2buyit/meta/json/train_pairs_outerwear.json',
#  '/run/media/twoaday/data-storag/data-sets/where2buyit/meta/json/train_pairs_pants.json',
#  '/run/media/twoaday/data-storag/data-sets/where2buyit/meta/json/train_pairs_skirts.json',
#  '/run/media/twoaday/data-storag/data-sets/where2buyit/meta/json/train_pairs_tops.json']

# %%
row = [r for _, r in df_bags_pairs.loc[df_bags_pairs.photo == 6749 ].iterrows()][0]

img = requests.get(photos_df.loc[photos_df.photo_id == row['photo']].url.values[0]).content
img = Image.open(BytesIO(img))

bbox = row['bbox']
bbox = (bbox['left'], bbox['top'], bbox['left'] + bbox['width'], bbox['top'] + bbox['height'])
print('{0} crop: {1}'.format(img.size, bbox))
crop = img.crop(bbox)
print('{0} image cropped to {1}'.format(img.size, crop.size))
plt.imshow(img)
plt.show()
plt.imshow(crop)
plt.show()
# Out:
# (2100, 3000) crop: (240, 385, 715, 1850)
# (2100, 3000) image cropped to (475, 1465)

# %%
path = '/run/media/twoaday/data-storag/data-sets/where2buyit/photos'
result = [y for x in os.walk(path) for y in glob.glob(os.path.join(x[0], '*.jpg'))]
df_data_set = []
for file in tqdm_notebook(result, desc = 'Parsing files'):
    s = file.split('/')
    name, product, category = s[-1].replace('.jpg', ''), s[-2], s[-3]
    df_data_set.append([name, product, category, file])
df_data_set = pd.DataFrame(df_data_set)
df_data_set.columns = ['name', 'product', 'category', 'file']
# Out:
# HBox(children=(IntProgress(value=0, description='Parsing files', max=7748, style=ProgressStyle(description_wid…

# %%
df_data_set.head()
# Out:
#     name product category                                               file
# 0  query    4940     bags  /run/media/twoaday/data-storag/data-sets/where...
# 1  46773    4940     bags  /run/media/twoaday/data-storag/data-sets/where...
# 2  46774    4940     bags  /run/media/twoaday/data-storag/data-sets/where...
# 3  46775    4940     bags  /run/media/twoaday/data-storag/data-sets/where...
# 4  query    4519     bags  /run/media/twoaday/data-storag/data-sets/where...

# %%
df_data_set.groupby('category').count()[['file']]
# Out:
#            file
# category
# bags        600
# belts        49
# dresses    1864
# eyewear      40
# footwear    887
# hats        171
# leggings    345
# outerwear   912
# pants       376
# skirts      896
# tops       1608

# %%
len(df_data_set) - len(df_data_set.loc[df_data_set.name == 'query'])
# Out:
# 5788

# %%
queries = df_data_set.loc[df_data_set.name == 'query'].values

# %%
len(queries)
# Out:
# 1960

# %%
queries_dict = {}
for s in queries[:,(1,3)]:
    queries_dict[s[0]] = s[1]
queries_dict
# Out:
# {'4940': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/4940/query.jpg',
#  '4519': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/4519/query.jpg',
#  '7894': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/7894/query.jpg',
#  '1635': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/1635/query.jpg',
#  '6025': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/6025/query.jpg',
#  '5737': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/5737/query.jpg',
#  '10650': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/10650/query.jpg',
#  '7276': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/7276/query.jpg',
#  '9136': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/9136/query.jpg',
#  '6176': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/6176/query.jpg',
#  '2779': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/2779/query.jpg',
#  '3832': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/3832/query.jpg',
#  '10227': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/10227/query.jpg',
#  '9638': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/9638/query.jpg',
#  '9661': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/9661/query.jpg',
#  '110': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/110/query.jpg',
#  '9250': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/9250/query.jpg',
#  '8372': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/8372/query.jpg',
#  '4341': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/4341/query.jpg',
#  '3156': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/3156/query.jpg',
#  '4039': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/4039/query.jpg',
#  '9391': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/tops/9391/query.jpg',
#  '10202': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/10202/query.jpg',
#  '1651': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/1651/query.jpg',
#  '3901': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/3901/query.jpg',
#  '8905': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/8905/query.jpg',
#  '3952': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/3952/query.jpg',
#  '3941': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/3941/query.jpg',
#  '9043': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/9043/query.jpg',
#  '376': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/tops/376/query.jpg',
#  '4917': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/4917/query.jpg',
#  '5069': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/5069/query.jpg',
#  '7147': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/7147/query.jpg',
#  '2982': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/2982/query.jpg',
#  '2573': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/2573/query.jpg',
#  '9927': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/9927/query.jpg',
#  '10659': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/10659/query.jpg',
#  '7322': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/7322/query.jpg',
#  '10210': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/10210/query.jpg',
#  '4336': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/4336/query.jpg',
#  '1752': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/1752/query.jpg',
#  '9010': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/tops/9010/query.jpg',
#  '8690': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/8690/query.jpg',
#  '2608': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/2608/query.jpg',
#  '5512': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/5512/query.jpg',
#  '133': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/133/query.jpg',
#  '4490': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/4490/query.jpg',
#  '9681': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/9681/query.jpg',
#  '3092': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/3092/query.jpg',
#  '9509': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/9509/query.jpg',
#  '4347': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/4347/query.jpg',
#  '3006': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/3006/query.jpg',
#  '6429': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/6429/query.jpg',
#  '2661': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/2661/query.jpg',
#  '2369': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/2369/query.jpg',
#  '10503': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/10503/query.jpg',
#  '4510': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/4510/query.jpg',
#  '6482': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/6482/query.jpg',
#  '1340': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/1340/query.jpg',
#  '9079': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/9079/query.jpg',
#  '1556': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/1556/query.jpg',
#  '9747': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/outerwear/9747/query.jpg',
#  '3264': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/3264/query.jpg',
#  '5585': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/5585/query.jpg',
#  '4747': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/4747/query.jpg',
#  '7874': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/7874/query.jpg',
#  '10386': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/10386/query.jpg',
#  '7063': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/7063/query.jpg',
#  '10160': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/10160/query.jpg',
#  '5843': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/skirts/5843/query.jpg',
#  '4975': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/4975/query.jpg',
#  '418': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/418/query.jpg',
#  '7429': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/7429/query.jpg',
#  '3919': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/3919/query.jpg',
#  '6909': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/6909/query.jpg',
#  '9413': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/9413/query.jpg',
#  '10299': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/10299/query.jpg',
#  '7697': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/7697/query.jpg',
#  '9340': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/9340/query.jpg',
#  '1510': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/1510/query.jpg',
#  '5570': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/5570/query.jpg',
#  '8911': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/8911/query.jpg',
#  '6765': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/6765/query.jpg',
#  '7907': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/7907/query.jpg',
#  '10700': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/10700/query.jpg',
#  '1492': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/1492/query.jpg',
#  '658': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/658/query.jpg',
#  '3426': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/3426/query.jpg',
#  '2288': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/2288/query.jpg',
#  '8731': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/8731/query.jpg',
#  '5207': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/5207/query.jpg',
#  '2054': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/2054/query.jpg',
#  '10884': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/10884/query.jpg',
#  '4142': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/4142/query.jpg',
#  '1109': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/skirts/1109/query.jpg',
#  '3031': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/3031/query.jpg',
#  '995': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/995/query.jpg',
#  '768': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/768/query.jpg',
#  '1380': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/1380/query.jpg',
#  '7149': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/7149/query.jpg',
#  '10221': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/10221/query.jpg',
#  '3916': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/3916/query.jpg',
#  '6448': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/6448/query.jpg',
#  '7350': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/skirts/7350/query.jpg',
#  '10953': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/10953/query.jpg',
#  '8279': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/8279/query.jpg',
#  '6324': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/6324/query.jpg',
#  '7738': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/7738/query.jpg',
#  '9867': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/9867/query.jpg',
#  '3932': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/3932/query.jpg',
#  '5158': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/5158/query.jpg',
#  '9224': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/9224/query.jpg',
#  '3341': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/3341/query.jpg',
#  '9945': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/9945/query.jpg',
#  '9810': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/9810/query.jpg',
#  '1763': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/1763/query.jpg',
#  '6922': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/6922/query.jpg',
#  '992': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/992/query.jpg',
#  '2518': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/2518/query.jpg',
#  '9550': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/9550/query.jpg',
#  '3526': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/3526/query.jpg',
#  '1265': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/1265/query.jpg',
#  '781': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/781/query.jpg',
#  '5189': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/5189/query.jpg',
#  '1350': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/1350/query.jpg',
#  '5287': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/5287/query.jpg',
#  '1721': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/1721/query.jpg',
#  '10172': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/10172/query.jpg',
#  '2781': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/2781/query.jpg',
#  '6377': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/6377/query.jpg',
#  '7786': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/7786/query.jpg',
#  '9190': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/9190/query.jpg',
#  '3462': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/3462/query.jpg',
#  '4000': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/pants/4000/query.jpg',
#  '6340': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/6340/query.jpg',
#  '2461': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/2461/query.jpg',
#  '8639': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/8639/query.jpg',
#  '4593': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/4593/query.jpg',
#  '10562': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/10562/query.jpg',
#  '5101': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/skirts/5101/query.jpg',
#  '3788': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/3788/query.jpg',
#  '8278': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/8278/query.jpg',
#  '7067': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/7067/query.jpg',
#  '1524': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/1524/query.jpg',
#  '1798': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/1798/query.jpg',
#  '10384': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/10384/query.jpg',
#  '9316': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/tops/9316/query.jpg',
#  '250': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/250/query.jpg',
#  '2557': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/2557/query.jpg',
#  '7672': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/bags/7672/query.jpg',
#  '950': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/belts/950/query.jpg',
#  '608': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/belts/608/query.jpg',
#  '81': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/belts/81/query.jpg',
#  '889': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/belts/889/query.jpg',
#  '438': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/belts/438/query.jpg',
#  '178': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/belts/178/query.jpg',
#  '112': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/112/query.jpg',
#  '811': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/belts/811/query.jpg',
#  '459': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/belts/459/query.jpg',
#  '113': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/belts/113/query.jpg',
#  '67': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/belts/67/query.jpg',
#  '220': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/belts/220/query.jpg',
#  '43': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/belts/43/query.jpg',
#  '22363': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/22363/query.jpg',
#  '60429': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/60429/query.jpg',
#  '66343': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/66343/query.jpg',
#  '21002': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/21002/query.jpg',
#  '2480': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/2480/query.jpg',
#  '6155': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/6155/query.jpg',
#  '25078': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/25078/query.jpg',
#  '19207': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/19207/query.jpg',
#  '7376': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/7376/query.jpg',
#  '18509': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/18509/query.jpg',
#  '6813': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/6813/query.jpg',
#  '18263': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/18263/query.jpg',
#  '4948': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/4948/query.jpg',
#  '54019': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/54019/query.jpg',
#  '39575': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/39575/query.jpg',
#  '37868': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/37868/query.jpg',
#  '62743': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/62743/query.jpg',
#  '14718': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/14718/query.jpg',
#  '63933': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/63933/query.jpg',
#  '3679': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/3679/query.jpg',
#  '57702': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/57702/query.jpg',
#  '48733': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/48733/query.jpg',
#  '55375': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/55375/query.jpg',
#  '27204': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/footwear/27204/query.jpg',
#  '60742': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/60742/query.jpg',
#  '40255': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/40255/query.jpg',
#  '51272': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/51272/query.jpg',
#  '53341': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/53341/query.jpg',
#  '54223': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/54223/query.jpg',
#  '22296': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/22296/query.jpg',
#  '7825': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/7825/query.jpg',
#  '17221': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/17221/query.jpg',
#  '27161': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/27161/query.jpg',
#  '65339': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/65339/query.jpg',
#  '9244': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/9244/query.jpg',
#  '67134': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/67134/query.jpg',
#  '60352': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/60352/query.jpg',
#  '52971': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/52971/query.jpg',
#  '42594': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/42594/query.jpg',
#  '33638': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/33638/query.jpg',
#  '45801': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/45801/query.jpg',
#  '31748': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/31748/query.jpg',
#  '4866': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/4866/query.jpg',
#  '62376': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/62376/query.jpg',
#  '32440': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/32440/query.jpg',
#  '61916': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/61916/query.jpg',
#  '3184': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/3184/query.jpg',
#  '41060': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/41060/query.jpg',
#  '53907': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/53907/query.jpg',
#  '59376': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/59376/query.jpg',
#  '26225': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/26225/query.jpg',
#  '53352': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/53352/query.jpg',
#  '9996': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/9996/query.jpg',
#  '63537': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/63537/query.jpg',
#  '13097': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/13097/query.jpg',
#  '28155': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/28155/query.jpg',
#  '31089': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/31089/query.jpg',
#  '6294': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/6294/query.jpg',
#  '36002': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/36002/query.jpg',
#  '3030': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/3030/query.jpg',
#  '39378': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/39378/query.jpg',
#  '4041': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/4041/query.jpg',
#  '33497': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/33497/query.jpg',
#  '57859': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/57859/query.jpg',
#  '49058': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/49058/query.jpg',
#  '58556': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/58556/query.jpg',
#  '45506': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/45506/query.jpg',
#  '40055': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/40055/query.jpg',
#  '53646': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/53646/query.jpg',
#  '11121': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/11121/query.jpg',
#  '2435': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/2435/query.jpg',
#  '28696': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/28696/query.jpg',
#  '12442': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/12442/query.jpg',
#  '5289': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/footwear/5289/query.jpg',
#  '38246': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/38246/query.jpg',
#  '21572': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/21572/query.jpg',
#  '12119': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/12119/query.jpg',
#  '25924': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/25924/query.jpg',
#  '63590': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/63590/query.jpg',
#  '15251': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/15251/query.jpg',
#  '30557': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/30557/query.jpg',
#  '7736': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/7736/query.jpg',
#  '28537': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/28537/query.jpg',
#  '58485': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/58485/query.jpg',
#  '63903': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/63903/query.jpg',
#  '41982': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/41982/query.jpg',
#  '138': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/138/query.jpg',
#  '63210': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/63210/query.jpg',
#  '34814': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/34814/query.jpg',
#  '21133': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/21133/query.jpg',
#  '26349': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/26349/query.jpg',
#  '773': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/773/query.jpg',
#  '18511': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/18511/query.jpg',
#  '53976': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/53976/query.jpg',
#  '6656': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/6656/query.jpg',
#  '6903': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/6903/query.jpg',
#  '53538': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/53538/query.jpg',
#  '3026': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/3026/query.jpg',
#  '47246': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/47246/query.jpg',
#  '55667': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/55667/query.jpg',
#  '20199': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/20199/query.jpg',
#  '65777': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/65777/query.jpg',
#  '62473': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/62473/query.jpg',
#  '10811': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/10811/query.jpg',
#  '28207': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/28207/query.jpg',
#  '9634': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/9634/query.jpg',
#  '44952': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/44952/query.jpg',
#  '40799': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/40799/query.jpg',
#  '5839': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/5839/query.jpg',
#  '39498': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/39498/query.jpg',
#  '66759': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/66759/query.jpg',
#  '28287': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/28287/query.jpg',
#  '3569': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/3569/query.jpg',
#  '31287': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/31287/query.jpg',
#  '19523': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/19523/query.jpg',
#  '21391': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/21391/query.jpg',
#  '53824': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/53824/query.jpg',
#  '38425': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/38425/query.jpg',
#  '67260': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/67260/query.jpg',
#  '22970': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/22970/query.jpg',
#  '19833': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/19833/query.jpg',
#  '17680': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/17680/query.jpg',
#  '56085': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/56085/query.jpg',
#  '28303': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/28303/query.jpg',
#  '65084': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/65084/query.jpg',
#  '66202': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/66202/query.jpg',
#  '3655': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/3655/query.jpg',
#  '60154': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/60154/query.jpg',
#  '17272': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/17272/query.jpg',
#  '51114': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/51114/query.jpg',
#  '2227': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/2227/query.jpg',
#  '18221': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/18221/query.jpg',
#  '23916': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/23916/query.jpg',
#  '13282': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/13282/query.jpg',
#  '26530': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/26530/query.jpg',
#  '63780': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/63780/query.jpg',
#  '61372': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/61372/query.jpg',
#  '57746': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/57746/query.jpg',
#  '9328': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/9328/query.jpg',
#  '28030': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/28030/query.jpg',
#  '54983': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/54983/query.jpg',
#  '19156': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/19156/query.jpg',
#  '50499': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/50499/query.jpg',
#  '12465': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/12465/query.jpg',
#  '5764': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/5764/query.jpg',
#  '44379': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/44379/query.jpg',
#  '28730': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/28730/query.jpg',
#  '64790': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/64790/query.jpg',
#  '62029': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/62029/query.jpg',
#  '51546': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/51546/query.jpg',
#  '44961': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/44961/query.jpg',
#  '55001': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/55001/query.jpg',
#  '55545': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/55545/query.jpg',
#  '52010': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/52010/query.jpg',
#  '13059': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/13059/query.jpg',
#  '52586': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/52586/query.jpg',
#  '31580': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/31580/query.jpg',
#  '22939': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/22939/query.jpg',
#  '45216': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/45216/query.jpg',
#  '48636': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/48636/query.jpg',
#  '50173': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/50173/query.jpg',
#  '33715': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/33715/query.jpg',
#  '9582': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/9582/query.jpg',
#  '41344': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/41344/query.jpg',
#  '48505': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/48505/query.jpg',
#  '10552': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/10552/query.jpg',
#  '52165': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/52165/query.jpg',
#  '67081': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/67081/query.jpg',
#  '19048': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/19048/query.jpg',
#  '12193': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/12193/query.jpg',
#  '6855': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/6855/query.jpg',
#  '31988': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/31988/query.jpg',
#  '3924': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/3924/query.jpg',
#  '14329': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/14329/query.jpg',
#  '57464': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/57464/query.jpg',
#  '23427': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/23427/query.jpg',
#  '63235': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/63235/query.jpg',
#  '14810': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/14810/query.jpg',
#  '5488': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/5488/query.jpg',
#  '1829': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/1829/query.jpg',
#  '54669': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/54669/query.jpg',
#  '42318': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/42318/query.jpg',
#  '66370': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/66370/query.jpg',
#  '34187': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/34187/query.jpg',
#  '47234': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/47234/query.jpg',
#  '41427': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/41427/query.jpg',
#  '55626': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/55626/query.jpg',
#  '55868': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/55868/query.jpg',
#  '31207': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/31207/query.jpg',
#  '21899': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/21899/query.jpg',
#  '34307': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/34307/query.jpg',
#  '3779': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/3779/query.jpg',
#  '21756': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/21756/query.jpg',
#  '41235': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/41235/query.jpg',
#  '57978': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/57978/query.jpg',
#  '27317': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/27317/query.jpg',
#  '64824': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/64824/query.jpg',
#  '56445': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/56445/query.jpg',
#  '30539': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/30539/query.jpg',
#  '14398': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/14398/query.jpg',
#  '32119': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/32119/query.jpg',
#  '15877': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/15877/query.jpg',
#  '33961': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/33961/query.jpg',
#  '17899': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/17899/query.jpg',
#  '51279': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/51279/query.jpg',
#  '33811': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/33811/query.jpg',
#  '41804': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/41804/query.jpg',
#  '57087': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/57087/query.jpg',
#  '44349': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/44349/query.jpg',
#  '17706': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/17706/query.jpg',
#  '17235': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/17235/query.jpg',
#  '30734': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/30734/query.jpg',
#  '41726': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/41726/query.jpg',
#  '33720': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/33720/query.jpg',
#  '11520': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/11520/query.jpg',
#  '64758': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/64758/query.jpg',
#  '29305': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/29305/query.jpg',
#  '22247': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/22247/query.jpg',
#  '7637': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/7637/query.jpg',
#  '20858': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/20858/query.jpg',
#  '22499': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/22499/query.jpg',
#  '36602': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/36602/query.jpg',
#  '28693': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/28693/query.jpg',
#  '770': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/770/query.jpg',
#  '39909': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/39909/query.jpg',
#  '44855': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/44855/query.jpg',
#  '28026': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/28026/query.jpg',
#  '24498': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/24498/query.jpg',
#  '870': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/870/query.jpg',
#  '37168': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/37168/query.jpg',
#  '9117': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/9117/query.jpg',
#  '54946': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/54946/query.jpg',
#  '50734': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/50734/query.jpg',
#  '32743': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/32743/query.jpg',
#  '4938': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/4938/query.jpg',
#  '51172': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/51172/query.jpg',
#  '12746': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/12746/query.jpg',
#  '17574': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/17574/query.jpg',
#  '48113': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/48113/query.jpg',
#  '35851': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/35851/query.jpg',
#  '44134': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/44134/query.jpg',
#  '17957': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/17957/query.jpg',
#  '12371': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/12371/query.jpg',
#  '65202': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/65202/query.jpg',
#  '61566': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/61566/query.jpg',
#  '58474': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/58474/query.jpg',
#  '50087': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/50087/query.jpg',
#  '18940': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/tops/18940/query.jpg',
#  '19756': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/19756/query.jpg',
#  '881': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/skirts/881/query.jpg',
#  '17456': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/17456/query.jpg',
#  '23985': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/23985/query.jpg',
#  '40960': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/40960/query.jpg',
#  '3547': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/3547/query.jpg',
#  '41405': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/41405/query.jpg',
#  '37281': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/37281/query.jpg',
#  '41849': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/41849/query.jpg',
#  '17318': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/17318/query.jpg',
#  '42953': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/42953/query.jpg',
#  '19143': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/19143/query.jpg',
#  '25208': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/25208/query.jpg',
#  '9630': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/9630/query.jpg',
#  '46114': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/46114/query.jpg',
#  '52415': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/52415/query.jpg',
#  '23118': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/23118/query.jpg',
#  '32167': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/32167/query.jpg',
#  '66216': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/66216/query.jpg',
#  '66153': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/66153/query.jpg',
#  '55126': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/55126/query.jpg',
#  '10123': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/10123/query.jpg',
#  '8766': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/8766/query.jpg',
#  '3292': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/3292/query.jpg',
#  '43866': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/43866/query.jpg',
#  '45568': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/45568/query.jpg',
#  '55068': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/55068/query.jpg',
#  '46433': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/46433/query.jpg',
#  '20537': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/20537/query.jpg',
#  '19636': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/19636/query.jpg',
#  '34709': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/34709/query.jpg',
#  '38120': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/38120/query.jpg',
#  '64938': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/64938/query.jpg',
#  '33419': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/33419/query.jpg',
#  '47055': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/47055/query.jpg',
#  '37570': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/37570/query.jpg',
#  '49255': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/49255/query.jpg',
#  '3358': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/3358/query.jpg',
#  '22326': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/22326/query.jpg',
#  '58008': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/58008/query.jpg',
#  '24014': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/24014/query.jpg',
#  '47097': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/47097/query.jpg',
#  '22359': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/22359/query.jpg',
#  '13992': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/13992/query.jpg',
#  '62053': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/62053/query.jpg',
#  '26238': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/26238/query.jpg',
#  '27036': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/27036/query.jpg',
#  '19158': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/19158/query.jpg',
#  '19975': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/19975/query.jpg',
#  '43399': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/43399/query.jpg',
#  '60591': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/60591/query.jpg',
#  '268': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/268/query.jpg',
#  '28482': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/28482/query.jpg',
#  '58897': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/58897/query.jpg',
#  '54228': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/54228/query.jpg',
#  '65345': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/65345/query.jpg',
#  '1665': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/1665/query.jpg',
#  '7299': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/7299/query.jpg',
#  '60789': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/60789/query.jpg',
#  '47438': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/47438/query.jpg',
#  '22762': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/22762/query.jpg',
#  '38946': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/38946/query.jpg',
#  '31262': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/31262/query.jpg',
#  '64302': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/64302/query.jpg',
#  '11704': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/11704/query.jpg',
#  '42869': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/42869/query.jpg',
#  '51700': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/51700/query.jpg',
#  '25163': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/25163/query.jpg',
#  '46757': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/46757/query.jpg',
#  '63371': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/63371/query.jpg',
#  '20360': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/20360/query.jpg',
#  '38298': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/38298/query.jpg',
#  '45613': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/45613/query.jpg',
#  '26840': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/26840/query.jpg',
#  '39976': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/39976/query.jpg',
#  '36400': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/36400/query.jpg',
#  '51470': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/51470/query.jpg',
#  '22838': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/22838/query.jpg',
#  '19332': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/19332/query.jpg',
#  '21883': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/21883/query.jpg',
#  '61172': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/61172/query.jpg',
#  '24464': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/24464/query.jpg',
#  '12753': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/12753/query.jpg',
#  '47224': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/47224/query.jpg',
#  '46395': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/46395/query.jpg',
#  '57846': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/57846/query.jpg',
#  '35344': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/35344/query.jpg',
#  '14771': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/14771/query.jpg',
#  '42405': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/42405/query.jpg',
#  '25084': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/25084/query.jpg',
#  '5128': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/5128/query.jpg',
#  '14089': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/tops/14089/query.jpg',
#  '40492': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/dresses/40492/query.jpg',
# ...
#  '18499': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/footwear/18499/query.jpg',
#  '14163': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/footwear/14163/query.jpg',
#  '43270': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/footwear/43270/query.jpg',
#  '14546': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/footwear/14546/query.jpg',
#  '6657': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/footwear/6657/query.jpg',
#  '6269': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/footwear/6269/query.jpg',
#  '8479': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/tops/8479/query.jpg',
#  '37436': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/footwear/37436/query.jpg',
#  '11211': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/footwear/11211/query.jpg',
#  '6162': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/footwear/6162/query.jpg',
#  '30187': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/footwear/30187/query.jpg',
#  '20797': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/footwear/20797/query.jpg',
#  '3188': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/footwear/3188/query.jpg',
#  '17292': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/footwear/17292/query.jpg',
#  '3530': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/footwear/3530/query.jpg',
#  '38014': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/footwear/38014/query.jpg',
#  '8618': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/footwear/8618/query.jpg',
#  '38173': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/footwear/38173/query.jpg',
#  '25311': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/footwear/25311/query.jpg',
#  '39512': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/footwear/39512/query.jpg',
#  '14366': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/footwear/14366/query.jpg',
#  '33942': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/footwear/33942/query.jpg',
#  '23340': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/footwear/23340/query.jpg',
#  '38544': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/footwear/38544/query.jpg',
#  '12192': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/footwear/12192/query.jpg',
#  '1453': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/1453/query.jpg',
#  '489': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/489/query.jpg',
#  '1500': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/1500/query.jpg',
#  '1205': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/1205/query.jpg',
#  '1599': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/1599/query.jpg',
#  '1655': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/1655/query.jpg',
#  '1288': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/1288/query.jpg',
#  '163': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/163/query.jpg',
#  '1629': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/1629/query.jpg',
#  '143': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/143/query.jpg',
#  '635': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/635/query.jpg',
#  '692': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/skirts/692/query.jpg',
#  '1237': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/1237/query.jpg',
#  '454': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/454/query.jpg',
#  '1241': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/1241/query.jpg',
#  '624': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/624/query.jpg',
#  '687': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/687/query.jpg',
#  '938': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/pants/938/query.jpg',
#  '794': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/794/query.jpg',
#  '273': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/273/query.jpg',
#  '1433': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/1433/query.jpg',
#  '1283': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/1283/query.jpg',
#  '1687': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/1687/query.jpg',
#  '1555': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/tops/1555/query.jpg',
#  '266': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/266/query.jpg',
#  '1466': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/1466/query.jpg',
#  '515': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/515/query.jpg',
#  '1010': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/1010/query.jpg',
#  '1506': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/1506/query.jpg',
#  '1072': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/1072/query.jpg',
#  '713': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/713/query.jpg',
#  '191': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/191/query.jpg',
#  '465': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/465/query.jpg',
#  '1212': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/1212/query.jpg',
#  '1566': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/1566/query.jpg',
#  '55': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/55/query.jpg',
#  '1360': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/1360/query.jpg',
#  '997': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/997/query.jpg',
#  '554': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/554/query.jpg',
#  '972': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/972/query.jpg',
#  '1329': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/1329/query.jpg',
#  '1270': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/1270/query.jpg',
#  '530': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/530/query.jpg',
#  '510': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/510/query.jpg',
#  '380': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/380/query.jpg',
#  '1512': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/hats/1512/query.jpg',
#  '683': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/683/query.jpg',
#  '2948': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/2948/query.jpg',
#  '473': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/473/query.jpg',
#  '2226': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/pants/2226/query.jpg',
#  '492': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/pants/492/query.jpg',
#  '3680': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/3680/query.jpg',
#  '1575': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/1575/query.jpg',
#  '619': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/619/query.jpg',
#  '2807': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/2807/query.jpg',
#  '2209': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/2209/query.jpg',
#  '2436': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/2436/query.jpg',
#  '2425': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/2425/query.jpg',
#  '1528': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/1528/query.jpg',
#  '3970': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/3970/query.jpg',
#  '3190': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/3190/query.jpg',
#  '1849': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/1849/query.jpg',
#  '1244': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/outerwear/1244/query.jpg',
#  '1088': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/1088/query.jpg',
#  '3600': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/3600/query.jpg',
#  '3143': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/3143/query.jpg',
#  '103': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/103/query.jpg',
#  '2884': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/2884/query.jpg',
#  '3401': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/3401/query.jpg',
#  '3150': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/3150/query.jpg',
#  '2026': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/2026/query.jpg',
#  '275': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/275/query.jpg',
#  '2609': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/2609/query.jpg',
#  '3956': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/3956/query.jpg',
#  '2146': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/skirts/2146/query.jpg',
#  '3586': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/3586/query.jpg',
#  '8': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/8/query.jpg',
#  '3885': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/3885/query.jpg',
#  '4060': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/4060/query.jpg',
#  '3257': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/3257/query.jpg',
#  '482': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/482/query.jpg',
#  '1152': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/1152/query.jpg',
#  '4112': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/4112/query.jpg',
#  '2147': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/2147/query.jpg',
#  '2199': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/2199/query.jpg',
#  '3211': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/3211/query.jpg',
#  '1701': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/1701/query.jpg',
#  '702': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/702/query.jpg',
#  '1539': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/1539/query.jpg',
#  '1994': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/1994/query.jpg',
#  '536': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/536/query.jpg',
#  '3523': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/3523/query.jpg',
#  '1130': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/1130/query.jpg',
#  '2691': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/2691/query.jpg',
#  '2334': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/2334/query.jpg',
#  '2316': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/2316/query.jpg',
#  '4085': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/4085/query.jpg',
#  '1784': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/1784/query.jpg',
#  '1077': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/1077/query.jpg',
#  '2984': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/2984/query.jpg',
#  '2606': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/2606/query.jpg',
#  '1944': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/1944/query.jpg',
#  '854': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/854/query.jpg',
#  '4117': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/4117/query.jpg',
#  '1381': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/1381/query.jpg',
#  '4044': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/4044/query.jpg',
#  '3647': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/3647/query.jpg',
#  '1090': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/1090/query.jpg',
#  '736': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/736/query.jpg',
#  '2788': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/outerwear/2788/query.jpg',
#  '627': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/627/query.jpg',
#  '3972': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/3972/query.jpg',
#  '1268': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/1268/query.jpg',
#  '2237': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/2237/query.jpg',
#  '3306': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/3306/query.jpg',
#  '1058': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/1058/query.jpg',
#  '2632': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/2632/query.jpg',
#  '1462': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/1462/query.jpg',
#  '1022': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/1022/query.jpg',
#  '2075': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/2075/query.jpg',
#  '2569': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/2569/query.jpg',
#  '2261': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/2261/query.jpg',
#  '660': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/660/query.jpg',
#  '4136': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/4136/query.jpg',
#  '3371': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/3371/query.jpg',
#  '3010': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/3010/query.jpg',
#  '1166': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/1166/query.jpg',
#  '2725': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/2725/query.jpg',
#  '2693': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/2693/query.jpg',
#  '2109': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/pants/2109/query.jpg',
#  '1220': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/1220/query.jpg',
#  '2441': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/pants/2441/query.jpg',
#  '3444': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/3444/query.jpg',
#  '2010': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/2010/query.jpg',
#  '1224': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/1224/query.jpg',
#  '4139': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/4139/query.jpg',
#  '2831': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/2831/query.jpg',
#  '2376': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/2376/query.jpg',
#  '2201': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/2201/query.jpg',
#  '2959': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/2959/query.jpg',
#  '566': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/566/query.jpg',
#  '3029': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/3029/query.jpg',
#  '3729': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/outerwear/3729/query.jpg',
#  '1792': '/run/media/twoaday/data-storag/data-sets/where2buyit/photos/leggings/1792/query.jpg',
#  ...}
